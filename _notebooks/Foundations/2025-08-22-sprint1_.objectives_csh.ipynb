# %% [raw]
# ---
# assignment: true
# chat: true
# courses:
#   csh:
#     week: 4
# description: Master essential development tools and complete team onboarding through
#   hands-on setup, coding, and collaboration. Begin the process for Project-based Learning
#   (PBL) by launching into a project.
# grading_modules: true
# layout: post
# permalink: /sprint1/challenge/csh/
# title: Onboarding Challenge - Ground 0
# toc: true
# type: objectives
# ---

# %% [markdown]
# ## Task-Centered Introduction
#
# Welcome to the **Open Coding Society** — where you'll develop professional software engineering skills while building real projects with your classmates.
#
# ### The Challenge
#
# Starting a new development environment can be overwhelming. You will encounter unfamiliar tools, new workflows, new teammates, and problems that do not always have obvious answers.
#
# **This is your first challenge: learn to work in an unfamiliar development environment.**
#
# Instead of simply following a set of instructions, you will document your setup process, troubleshoot problems, make decisions, and create solutions that help both you and your teammates succeed.
#
# You are beginning to work as a **student developer**. Your work will include:
#
# * **Mastering professional development tools**
#
#   * VS Code
#   * GitHub
#   * Git
#   * Development and testing workflows
#
# * **Building web-based projects**
#
#   * Individual GitHub Pages portfolio
#   * Team project sites
#   * Project documentatio
#
# * **Developing collaboration practices**
#
#   * Issues
#   * Kanban boards
#   * GitHub workflows
#   * Team communication
#
# * **Beginning your course-specific development**
#
#   * **CSSE:** Begin ideation and development of a new game while learning the OCS game engine.
#   * **CSP:** Begin ideation and development of an OCS project or contribute to and extend a nonprofit project.
#   * **CSA:** Begin ideation, design, development, maintenance, and testing of an existing OCS system.
#   * **CSH:** Begin research and development focused on extending OCS intelligence.
#
# * **Documenting your learning journey**
#
#   * Setup instructions
#   * Troubleshooting notes
#   * Decisions and solutions
#   * Learning reflections
#
# This class mirrors the experience of **professional software engineering onboarding**. You are not expected to know everything when you begin. You are expected to learn how to find your way through unfamiliar problems.
#
# ### The Problem
#
# New developers often feel overwhelmed by unfamiliar tools, workflows, technologies, and expectations. A problem that seems simple can become difficult when you do not yet understand the environment in which you are working.
#
# Your job is not simply to get everything working and perfect it.
#
# **Your job is to learn how to get things working and keep improving.**
#
# That means learning how to investigate a problem, ask useful questions, find information, test possible solutions, document what you discover, and help the next person who encounters the same problem.
#
# ### The Goal
#
# By the end of the first onboarding sprint, you will:
#
# * **Build Your Personal Portfolio:** Have your individual GitHub Pages site online and validate that your required code runners and development tools are working.
# * **Build Working Proficiency:** Become comfortable using the essential tools and workflows required for your course.
# * **Establish Your Development Workflow:** Understand how you will create, test, document, and submit your work.
# * **Document Your Progress:** Create useful issues, Kanban boards, plans, and technical notes that guide your development.
# * **Begin Your Project:** Move from onboarding into meaningful development work appropriate to your course.
# * **Reflect on Your Learning:** Begin identifying what you know, what you do not yet know, how you respond to problems, and how your approach changes as you gain experience.
#
# ```mermaid
# mindmap
#   root((Student Developer))
#     🛠️ Develop Skills
#       VS Code
#       GitHub
#       Git
#       Development Workflow
#     🏗️ Build Projects
#       Team Collaboration
#       Individual Portfolio
#       GitHub Pages
#       Course Project
#     📝 Document Progress
#       Setup Instructions
#       Troubleshooting Notes
#       Issues
#       Plans
#       Learning Reflections
# ```
#
# **Professional software developers use these same tools and workflows when joining new teams, learning unfamiliar systems, and building applications.**
#
# ### Why This Matters
#
# The skills you develop during onboarding form the foundation for your future coursework.
#
# If you learn how to work effectively in an unfamiliar technical environment, you will spend less time fighting your tools and more time solving meaningful problems.
#
# More importantly, you will begin developing an engineering habit that will serve you throughout the year:
#
# > **Encounter a problem → investigate → experiment → solve → document → reflect → improve.**
#
# This onboarding challenge is the beginning of that process.

# %% [markdown]
# ## Activation — You Already Know More Than You Think
#
# > **You are a learner, a developer, and a teacher.**
# >
# > Every success, error, question, and breakthrough is something you can learn from — and something that may help someone else.
#
# You are not starting from zero.
#
# You have already spent years learning how to learn, solve problems, work with others, and respond when something does not make sense.
#
# ### What You Already Know
#
# | You've Used                  | Now You'll Use It As a Developer           |
# | ---------------------------- | ------------------------------------------ |
# | **Rubrics**                  | Define what "good" looks like              |
# | **Checklists**               | Build repeatable processes                 |
# | **Assessments**              | Test whether something works               |
# | **Feedback**                 | Improve your work                          |
# | **Teamwork**                 | Collaborate on a real project              |
# | **Creative Problem Solving** | Find solutions when there is no answer key |
#
# And you already know the basic progression of learning:
#
# **Remember → Understand → Apply → Analyze → Evaluate → Create**
#
# In software development, that might look like:
#
# **Know a command → understand what it does → use it → troubleshoot it → choose between solutions → build something new**
#
# That's the transition from **student** to **student developer**.
#
# ### Your Hidden Advantage
#
# You've spent more than a decade being a student.
#
# You've experienced:
#
# * Great instructions — and confusing ones
# * Helpful feedback — and feedback that wasn't
# * Teams that worked — and teams that struggled
# * Assignments that engaged you — and assignments that didn't
#
# **You already know what it feels like to be the learner.**
#
# Now you get to use that experience to become a better developer.
#
# ### The PBL Mindset
#
# Project-based learning changes the question.
#
# Instead of:
#
# > **"What does the teacher want me to do?"**
#
# Start asking:
#
# > **"What do I need to figure out to move the project forward?"**
#
# You will:
#
# **Encounter → Investigate → Experiment → Solve → Document → Reflect → Improve**
#
# ### Your Mission
#
# You are the beginner.
#
# That is an advantage.
#
# When something is confusing, **capture the confusion**.
#
# When something breaks, **document the solution**.
#
# When you discover a better way, **share it**.
#
# When your team struggles, **look for a better process**.
#
# Your struggles are not evidence that you are failing.
#
# **They are evidence that you are learning.**
#
# And what you learn can become the documentation, tools, and knowledge that help the next student succeed.

# %% [markdown]
# ## Demonstration — See the Tools and Workflow in Action
#
# > **Follow along:** Open your own VS Code workspace and GitHub repository as we work through this demonstration.
#
# So far, we've focused on **how you think and learn**.
#
# Now let's see the **development environment** you will use.
#
# ### The Foundation
#
# You will use these tools repeatedly throughout the year:
#
# | Tool                    | What It Does                                                          |
# | ----------------------- | --------------------------------------------------------------------- |
# | **VS Code**             | Write and edit Markdown, JavaScript, and other project files          |
# | **VS Code Marketplace** | Find and install extensions that improve your development environment |
# | **Make**                | Automate repetitive development tasks                                 |
# | **Git**                 | Track changes and build a history of your work                        |
# | **GitHub**              | Store, share, and collaborate on your code                            |
# | **GitHub Actions**      | Automatically build, test, and publish your projects                  |
# | **GitHub Pages**        | Publish your web projects                                             |
#
# ### Watch the Workflow
#
# The important thing is not learning each tool in isolation.
#
# **Watch how they work together.**
#
# ```mermaid
# flowchart LR
#     A[VS Code<br/>Create & Edit]
#     B[Make<br/>Build & Test]
#     C[Git<br/>Commit Changes]
#     D[GitHub<br/>Push & Sync]
#     E[GitHub Actions<br/>Automate]
#     F[GitHub Pages<br/>Publish]
#
#     A --> B --> C --> D --> E --> F
# ```
#
# ### What You'll See
#
# During the demonstration, we will:
#
# 1. **Open VS Code** and review the key extensions.
# 2. **Explore this notebook** and the Markdown used to create it.
# 3. **Make a change** to a file.
# 4. **Build or test the change** using Make.
# 5. **Commit the change** using Git through VS Code.
# 6. **Push the commit to GitHub.**
# 7. **Watch GitHub Actions** run automatically.
# 8. **Verify the published result** on GitHub Pages.
#
#
# ### From Tools to Software Development
#
# These tools support the **Software Development Lifecycle (SDLC)**.
#
# As you progress, the simple onboarding loop will grow into a larger engineering workflow:
#
# ```mermaid
# flowchart TD
#     A[Plan<br/>Issues & Backlog]
#     B[Develop<br/>Code & Build]
#     C[Test<br/>Unit & System Tests]
#     D[Version<br/>Commit & Push]
#     E[Collaborate<br/>Review & Merge]
#     F[Deploy<br/>Publish]
#     G[Reflect<br/>Issues & Replan]
#
#     A --> B --> C --> D --> E --> F --> G
#     G --> A
# ```
#
#
# ### Development Practices
#
# The onboarding challenge is the entry point to a the set of development practices.
#
# | Practice | Purpose |
# |---|---|
# | **Tools & Equipment** | The development environment used to build, test, and deploy software. |
# | **GitHub Pages** | The framework for a web project — pages, layouts, Markdown, HTML, JavaScript, and how everything connects. |
# | **Agile Methodologies** | How teams organize work, make decisions, and select project teams. A key focus of Agile is to use short cycles and iterate often |
# | **Sprint Framework** | How work is organized into short, focused development cycles with checkpoints. |

# %% [markdown]
# ## Onboarding Objectives - Ground 0
#
# **Check your starting position.**
#
# You have spent **Weeks 0–1** setting up your development environment, working through guides, solving problems, and beginning to explore ideas according to your skill level.
#
# Now, as you enter **Weeks 2–3**, make sure you are ready to move your mind from:
#
# > **Onboarding → Project Development**
#
# | Section                                                            | Ready? |
# | ------------------------------------------------------------------ | ------ |
# | [**1. Understand the Challenge**](#1-understand-the-challenge)     | ☐ yes! |
# | [**2. My Development Environment**](#2-my-development-environment) | ☐ yes! |
# | [**3. My GitHub Workflow**](#3-my-github-workflow)                 | ☐ yes! |
# | [**4. Forming the Team**](#4-forming-the-team)                     | ☐ yes! |
# | [**5. Beginning the Project**](#5-beginning-the-project)           | ☐ yes! |
#
#
# ### 1. Understand the Challenge
#
# * [x] I understand that the goal was not simply to install tools, but to learn how to work through an unfamiliar development environment.
# * [x] I can identify at least one problem I encountered and explain how I solved or investigated it.
# * [x] I have documented something that could help another student.
# * [x] I have a story about how forming a team, positives and challenges.
# * [x] I have a story about starting a team project, positives and challenges.
# * [x] I can explain the **Onboarding Objectives** in my own words.
#
# ---
#
# ### 2. My Development Environment
#
# * [x] I can open my development environment and begin working without waiting for someone else.
# * [x] I can edit and preview the files I will use in my course.
# * [x] I can use Git/GitHub to commit and push my work.
# * [x] I know where to find the tool setup and troubleshooting guides.
# * [x] I know how to ask for help when I am stuck.
# * [x] I have a working strategy for my personal computer and development environment.
#
# ---
#
# ### 3. My GitHub Workflow
#
# * [x] I can locate my GitHub repository.
# * [x] I can create an issues in my GitHub repository location.
# * [x] I can commit a change in GitHub.
# * [x] I can create or edit a file in VSCode.
# * [x] I can commint and sync changes from VSCode to GitHub.
# * [x] I know about GitHub Actions and can determine if my site is working.
# * [x] I know how to load my GitHub Pages portfolio site in my browser.
#
# ---
#
# ### 4. Forming the Team
#
# #### Before Forming the Team
#
# * [x] I have completed or reviewed the team formation process.
# * [x] I have read an article on selecting effective development teams.
# * [x] I have identified my **persona, skills, interests, and strengths** in OCS.
# * [x] I understand the expectation for diversity of skills, interests, and perspectives when forming teams.
# * [x] I have considered which teammates I may work well with.
# * [x] I have sat in proximity to potential teammates.
#
# #### Establishing the Team
#
# * [x] I know my team members’ names.
# * [x] We have discussed our skills, interests, and perspectives.
# * [x] We have established a team communication channel.
# * [x] I have shared my preferred contact method with my teammates.
# * [x] We have established a team **Agile manifesto and communication protocols**.
#
# #### Beginning to Operate as a Team
#
# * [x] We have identified the coding challenges required for our course.
# * [x] We have created team and individual GitHub repositories.
# * [x] We have created team and individual GitHub issues, kanban, and milestones.
# * [x] We have begun team decision-making processes such as stand-ups, pin-ups, and burndowns.
# * [x] We have practiced Live Share, debugging, or pair programming.
# * [x] We have established a process for discussing problems and resolving issues.
# * [x] We have established our team contribution workflows: fork, branch, pull request, or direct collaboration as appropriate.
# * [x] We have identified how we will accept feedback and take action between checkpoints.
#
# ---
#
# ### 5. Beginning the Project
#
# * [ ] I have participated in project ideation.
# * [ ] I can describe at least one problem or project idea our team is considering.
# * [ ] I have contributed an idea, question, research finding, or technical consideration.
# * [ ] I have created or contributed to a GitHub issue related to our work.
# * [ ] We have established our first project direction.
# * [ ] I understand what tasks I am expected to accomplish before the next sprint checkpoint.
# * [ ] We have identified what the team needs to accomplish before the next checkpoint.
# * [ ] I know that presenting evidence is part of my responsibility as I work.
#
# ---
#
# ## Ground 0 Team Activities
#
# ### Team Formation
#
# **Understand → Introduce → Explore → Form**
#
# Read, discuss, and use the team-formation process to create groups based on **skills, interests, perspectives, and project needs**, rather than friendship alone.
#
# ### Team Initialization
#
# **Organize → Connect → Decide → Build**
#
# Establish the team's communication, GitHub workflow, coding practices, decision-making processes, and initial project direction.
#
# ### Team Practice
#
# **Communicate → Collaborate → Solve → Document**
#
# Begin practicing the behaviors expected throughout the sprint:
#
# * Daily checkpoints
# * Issue tracking
# * Pair programming
# * Live debugging
# * Peer support
# * Decision documentation
# * Evidence collection
# * Integration and Test policies
# * Preparing for Checkpoints and Demos

# %% [markdown]
# ## Technical & Learning Evaluation
#
# This checklist looks beyond whether you **completed a task**.
#
# Technical development includes **using tools, building solutions, solving problems, learning from mistakes, and becoming more independent**.
#
# Your evaluation should show not only **what you completed**, but how your technical ability changed during the sprint.
#
# ### Evaluation Matrix
#
# Supply a GitHub Issue with your **self-evaluation scores and one summary for each section**.
#
# > **Rank each area individually. Write one reflection for each section.**
# >
# > You do not need to write a separate response for every row.
#
# ### Tools & Development Environment
#
# | ID | Area | Self Rank | Peer | Teacher |
# |---|---|---:|:---:|:---:|
# | T01 | Development Environment | 4 | 3 | — |
# | T02 | VS Code | 3 | 4 | — |
# | T03 | Git / GitHub | 3 | 4 | — |
# | T04 | Portfolio / GitHub Pages | 4 | 3 | — |
#
# **Summary:**
# > I believe I perform relatively well with the basics. Upon the same token, however, I'm always learning new things about GitHub and VSCode every day. I have not completely mastered every aspect of these programs, but I believe I have demonstrated that I am able to do the important basics, such as PR, commit, make a new repo, manage it, and so on. I even helped a few new students set their tools up,and more.
#
# ---
#
# ### Development & Creation
#
# | ID | Area | Self Rank | Peer | Teacher |
# |---|---|---:|:---:|:---:|
# | T05 | Tools & Equipment Hacks | 4 | 4 | — |
# | T06 | Portfolio / Blogging Hacks | 4 | 4 | — |
# | T07 | Theme / Style / Layout | 2 | 4 | — |
# | T08 | JavaScript / Coding Challenges | 4 | 3 | — |
# | T09 | AI Orchestration | 3 | 3 | — |
#
# **Summary:**
# >Since we haven't done many big things this current sprint, I will bring up my multiplayer tag game from last year. This was an advanced, CSP level game where players connect to a server and play tag. The design process was extensively blogged, a lesson on how to impliment it and how it works was drafted, and it was a project that took around a month, with advanced challenges and blocks I had to face along the way. I relied on Slack and GitHub, where I would be able to communicate with our TA, Torrin, if I ran into an issue, and reference his backend server and change it and run it on my own. It was a long road, but it really helped me master my tools and skills a lot more than some of my peers.
#
# ---
#
# ### Technical Awareness & Communication
#
# | ID | Area | Self Rank | Peer | Teacher |
# |---|---|---:|:---:|:---:|
# | T10 | Tech / Cyber Growth | 4 | 4 | — |
# | T11 | Learning Through Mistakes | 4 | 4 | — |
# | T12 | Tech / Cyber Talk | 4 | 3 | — |
#
# **Summary:**
# I came into CSSE not knowing a thing about coding or computers. I think, throughout the past year and even the beginning of this year, I have grown tremendously. Exponentially, even. At the beginning of the year, if you asked me to explain simply what VSCode was, I wouldn't know where to start. I didn't know a thing. Now, I'm able to code a game on my own, git pull, git push, set up virtual environments, clone repos, PR, and with the right guidance, take on huge projects, like the multiplayer game.
#
#
# >
#
# ---
#
# ### Ranking Guidelines
#
# Rank each area based on the **technical ability you demonstrated during the sprint**.
#
# > **0 means you have not entered a rank yet.**
# >
# > Start with 1 and select the level that best represents your demonstrated ability.
#
# | Rank | Description |
# |---:|---|
# | **0** | **Not Entered** — No self-assessment has been entered yet. |
# | **1** | **Explore** — I have encountered or experimented with this technology or skill. |
# | **2** | **Understand** — I can explain it and perform basic tasks with support. |
# | **3** | **Apply** — I can use it independently in my project work. |
# | **4** | **Analyze / Evaluate** — I can troubleshoot problems, compare approaches, and improve my solution. |
# | **5** | **Create / Extend** — I can independently customize, extend, or create solutions using the skill. |
#
# **Peer / Teacher Calibration:** `−` = below self-assessment · `=` = consistent with self-assessment · `+` = above self-assessment
#
# ---
#
# ### Before the Evaluation
#
# * [x] I reviewed my **Ground 0 Checklist**.
# * [x] I reviewed the technical evidence collected during the sprint.
# * [x] I completed my self-ranking before receiving peer or teacher feedback.
# * [x] I can support my rankings with examples from my work.
# * [x] I identified at least one technical area where I want to improve.
#
# ### Peer Perspective
#
# With your team:
#
# * [x] I reviewed technical work or evidence from a teammate.
# * [x] I identified a technical strength a teammate demonstrated.
# * [x] I identified a constructive opportunity for a teammate to improve.
# * [x] My feedback is based on technical evidence or observed work rather than personal preference.
#
# ### Teacher Perspective
#
# The teacher will use **working code, repositories, commits, issues, demonstrations, documentation, troubleshooting, and discussions** to evaluate technical growth.
#
# ### Compare the Perspectives
#
# After the peer and teacher evaluations are complete:
#
# * [x] I compared my self-ranking with my peer ranking.
# * [ ] I compared my self-ranking with my teacher ranking.
# * [x] I identified an area where the perspectives agreed.
# * [x] I identified an area where the perspectives differed.
# * [x] I considered why the perspectives may have differed.
# * [x] I identified one specific technical action for my next sprint.
#
# ### Retrospective Question
#
# > **What can I do now as a developer that I could not do at the beginning of this sprint?**
# In terms of this year, I learned a lot more about Jekyll and themes. I can now implement and work with themes in ways I wasn't able to at the beginning of the year, and I now understand what a capstone project is and I am able to create one and alter it to my liking, not only to fit the requirements of my chosen non[rofit but to meet teacher expectations.]
#
# ### Strongest Technical Evidence
#
# **The technical evidence I am most proud of:**
#
# > I am most proud of my Multiplayer Game from my CSSE year. I was able to present it at the CTE expo a year early, it was a topic all of my peers had refused to take on, and I had such a blast creating and coding it with the help of my class's TA, and I was extrememly proud of the end result. I definitely discovered some sort of passion for coding and game development through this project, which is what makes me adore it so much.
#
# **The biggest technical problem I solved:**
#
# > One specific problem that stuck with me was our struggle to get other players to show on screen in our tag game. That's when I learned about stamping, and we used it to create a copy of the player character and stamp it onto the approximate locations of other players on screen. It was very interesting.
#
# **The technical skill I most need to improve:**
#
# > Perhaps my cyber talk. I'd like to extend my 'tech' vocabulary and be able to explain my projects and design processes with fancier terms. I feel like that would not only be benificial in the long run, but help in demonstrating mastry and understanding of certain topics. Learning vocabulary is generally goodeducation, as well.
#
# **My next technical learning goal:**
#
# > I'd like to extend my vocabulary, to be able to explain code and projects more clearly. I believe that is a good and reasonable goal to set, especially as we are just starting the year.

# %% [markdown]
# ## Professional Evaluation
#
# This checklist and its summaries look beyond technical tasks.
#
# Professional development includes **how you work, communicate, collaborate, respond to problems, and contribute to a team**.
#
# Your performance will be considered from three perspectives:
#
# **Self → Peer → Teacher**
#
# ### Evaluation Matrix
#
# Supply a GitHub Issue with your **self-evaluation scores and one summary for each section**.
#
# > **Rank each area individually. Write one reflection for each section.**
# >
# > You do not need to write a separate response for every row.
#
# ### Core Behaviors
#
# | ID | Area | Self Rank | Peer | Teacher |
# |---|---|---:|:---:|:---:|
# | P01 | Attendance / Tardy | 5 | 4 | — |
# | P02 | Work Habits | 3 | 4 | — |
# | P03 | Integrity | 4 | 4 | — |
#
# **Summary:**
# I think attendance is one of the few things I deserve a five for, funnily enough, because last year, I didn't miss a day of school, nor was I tardy to class. And This year, so far, I have yet to miss a day. I think I still need to work on my work habits, however, because I have a habit of getting so absorbed in my work where I stay up until 2 AM or later, which isn't something I would like to continue. Finally, I think taking ownership of your mistakes and accepting criticism is an important skill to have in every person. So its something I prioritize in my character, and something that has shown thoughout the time I have spent in this classroom, whether it be a faulty commit that accidentally changes files it shouldn't, to not meeting every requirement expected of me during certain assignments. Owning up to my mistakes and fixing them is more important than avoiding the blame.
#
#
#
# >
#
# ---
#
# ### Collaboration
#
# | ID | Area | Self Rank | Peer | Teacher |
# |---|---|---:|:---:|:---:|
# | P04 | Communication | 4 | 4 | — |
# | P05 | Help Seeking | 3 | 3 | — |
# | P06 | Mentoring / Advocacy | 4 | 4 | — |
#
# **Summary:**
# I communicated quite a bit with my teams in both years. This year, I created a team groupchat on the first day. Since then it has been used to clearly communicate to each team member their parts during this first sprint, and I frequently delegate my heavy workloads to my free teammates, ask questions, and answer many more. Like how recently, we used this groupchat to peer rank each other for this very assignment, as well as discuss our future plans for our capstone project. We were able to make marginal progress today through our brief reconcessions.
#
#
# >
#
# ---
#
# ### Professional Skills
#
# | ID | Area | Self Rank | Peer | Teacher |
# |---|---|---:|:---:|:---:|
# | P07 | Timeliness | 3 | 4 | — |
# | P08 | Persistence | 4 | 3 | — |
# | P09 | Organization | 2 | 4 | — |
# | P10 | Engagement | 4 | 3 | — |
#
# **Summary:**
# I think my timliness is a solid three, because although it is a lot better now, when I was still first starting out, there were a lot of projects I had to ask for extensions on because I wasn't able to manage the workload, on top of the insurrmountable errors I collected on the daily. I think I need to be a little more organized, specifically because I have a lot fo unused repositories and folders in my terminal, and sometimes I get lost and forget which repos are still active. I need to find the time to go through and reorganize my folders. I persistence and engagement go hand in hand, however, because I believe I am a natural leader and tend to take the responsibility of owning repos and sending PRs, communicating with other scrum masters and so on. I keep my role quite active.
#
#
# >
# ---
#
# ### Peer Summary - By Isha Chaturvedi
#
# From a teammate point of view Salma is a very well organized and straightforward person. She is very good with helping people and leading the team such as assigning jobs and splitting the work so that everyone has a hand in doing something. Her skillset is also very good as she is very good with tools and equipment as we all have been doing it for a while. Salma is also good with creativity and learning  new tasks such as the AI implementation last year and such, she has a very good technical skill set and is great at problem solving as our team runs into a lot of errors, like a lot. Overall salma is a good teammate ( scrum master ) and knows how to take lead and has the personality and skill to lead a team to success.
#
# ---
#
# ### Ranking Guidelines
#
# Rank each area based on the **behavior you demonstrated during the sprint**.
#
# > **0 means you have not entered a rank yet.**
# >
# > Start with 1 and select the level that best represents your demonstrated behavior.
#
# | Rank | Description |
# |---:|---|
# | **0** | **Not Entered** — No self-assessment has been entered yet. |
# | **1** | **Beginning** — I am beginning to recognize and practice this behavior. |
# | **2** | **Developing** — I demonstrate this behavior sometimes, usually with reminders or support. |
# | **3** | **Consistent** — I regularly demonstrate this behavior independently. |
# | **4** | **Strong** — I consistently demonstrate this behavior and adjust when circumstances change. |
# | **5** | **Model** — I consistently demonstrate this behavior and help others develop it. |
#
# **Peer / Teacher Calibration:** `−` = below self-assessment · `=` = consistent with self-assessment · `+` = above self-assessment
#
# ---
#
# ### Before the Evaluation
#
# * [x] I reviewed my **Ground 0 Checklist**.
# * [x] I reviewed the evidence collected during the sprint.
# * [x] I completed my self-ranking before receiving peer or teacher feedback.
# * [x] I can support my rankings with examples from my sprint.
# * [x] I identified at least one area where I want to improve.
#
# ### Peer Perspective
#
# With your team:
#
# * [x] I provided useful feedback to a teammate.
# * [x] I identified a strength that a teammate contributed to the project.
# * [x] I identified a constructive opportunity for a teammate to improve.
# * [x] My feedback is based on observed behavior or evidence rather than personal preference.
#
# ### Teacher Perspective
#
# The teacher will use **project evidence, observations, discussions, documentation, and team interactions** to evaluate growth.
#
# ### Compare the Perspectives
#
# After the peer and teacher evaluations are complete:
#
# * [ ] I compared my self-ranking with my peer ranking.
# * [ ] I compared my self-ranking with my teacher ranking.
# * [ ] I identified an area where the perspectives agreed.
# * [ ] I identified an area where the perspectives differed.
# * [ ] I considered why the perspectives may have differed.
# * [ ] I identified one specific action for my next sprint.
#
# ### Retrospective Question
#
# > **What did I learn about myself as a developer and teammate that I could not have learned from a grade alone?**
#
# I wouldn't have found any passion in the work I did if all it was was dishing out projects like a machine for a grade. Going through the ideation process with my teammates, dividing work, calling at night and slowly watching our vision come to life is so fun. If not given the chance to go through these important processes, I wouldn't have found code as fun as a have so far.
#
# ### Next Sprint Commitment
#
# **One professional behavior I will improve:**
#
# > I will manage my time and workload a lot better than I have this Sprint. It's too often that I stay up dealing with errors and separate issues, and rather than leaving them to fester and taking them all on in one night, despite the other activities I do outside of school, I should find the time to delegate more effort into spreading my workload out a little better.
#
# **One technical skill I will improve:**
#
# > I will improve my cyber talk. I would like to be able to explain and discuss code at a higher level than I already can, as it can prove benificial in the long run and will make it easier to get my point across, as well as demonstrate master and understanding of many important topics this year.
#
# **One way I will contribute more effectively to my team:**
#
# > Communicate with them more. I have a habit of taking the work on all by myself sometimes, rather than giving my teammates a part of my load that I can't handle and giving them chances to learn as well. To build team synergy and strengthen our group in general, wen need to be able to communicate and rely on each other when needed.
#
# **Evidence I will collect during the next sprint:**
#
# > I will blog my design, ideation, and coding processes, as well as document errors I come across in testing and discuss my thought process through each iteration of code. All of GitHub issues. this is one of the most effective ways for other developers to view and understand both your ideas and your code, as well as prove you put in a lot of work to your projects and stayed true to your goals and values.

# %% [markdown]
# ### Review – “Becoming proficient in Scrum Agile Workflow”
#
# At the end of the sprint, teams consolidate their growth and show how they’ve applied **technical, collaborative, and design skills**.
#
#
# ```mermaid
# flowchart TD
#     subgraph SR ["Sprint Review Cycle"]
#         A[Team Capability Review] --> B[Peer to Peer Presentation]
#         B --> C[Receive Feedback]
#         C --> D[Refinement & Iteration]
#         D --> E[Teacher Close-Out]
#         E --> F[Individual Mastery Review]
#         F --> G[Set Goals for Next Sprint]
#         G --> A
#     end
#
#     F --> H[Personal Growth]
#
# ```
